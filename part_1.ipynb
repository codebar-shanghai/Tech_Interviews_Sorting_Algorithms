# %% [markdown]
# _____________________________________________ Option 1 Timeline __________________________________________________________________
#
# (00:00 - 00:05) give people 5 extra minutes for late comers)
#
# (00:05 - 00:06) - Overview/ agenda
#
# (00:06 - 00:20) Ice Breaker: Rate your skill level based on a matrix and what is your favorite food(matrix for rating skills & example) Ex: My name is Lauren. My skill level x and my favorite food is y.
#
# (00:20 - 00:40) set up computers/ jupyter notebook for everyone
#
# (00:40 - 00:42) frontload with terms (algorithm/software design/sudo code/...)
#
# (00:42 - 01:00) I do: Merge Sort
#
# (1:00 - 01:25) We do: Quick Sort
#
#
# (1:25 - 01:35) Break
#
# Second Half
#
#
# (01:35 - 02:35) You do: SORTING ALG CHOICES
#
# (02:35 - 02:45) Closing remarks, Thank you's & good byes
#
# (02:45 - 03:00) Extra time for Q&A, solo work and conversation
#
#
# _____________________________________________ Option 2 Timeline __________________________________________________________________
#
#
# (00:00 - 00:05) give people 5 extra minutes for late comers)
#
# (00:05 - 00:06) - Overview/ agenda
#
# (00:06 - 00:20) Ice Breaker: Rate your skill level based on a matrix and what is your favorite food(matrix for rating skills & example) Ex: My name is Lauren. My skill level x and my favorite food is y.
#
# (00:20 - 00:40) set up computers/ jupyter notebook for everyone
#
# (00:40 - 00:42) frontload with terms (algorithm/software design/sudo code/...)
#
# (00:42 - 01:00) I do: Merge Sort w/ whole room pair coding
#
# (1:00 - 01:25) We do: Quick Sort w/ break points to dicuss
#
#
# (1:25 - 01:35) Break: when people come back have them sitting in a good mix of beginner to advanced on each row
#
# Second Half
#
#
# (01:35 - 02:35) You do pair coding: SORTING ALGORITHM X
#
# (02:35 - 02:45) Closing remarks, Thank you's & good byes, communicate portfolio projects below
#
# (02:45 - 03:00) Extra time for Q&A, solo work and conversation
#
# _____________________________________________ Blue print __________________________________________________________________
#
#
# What we are doing at each segment:
# - how to take notes on algorithms
# - what questions will are interviews asking? & how to use AI when studying to prepare correctly (eddie)
# - how to pair code
# - Need: list of questions: get some from books, leetcode and some from interviews
#
# (I do):(We do): (You do)
#
# 15:25:50
#
# Protfolio project:
#
# - Beginner: Step by step guide (bubble sort)
# - Advanced Beginner:  Provide sudo code and code the sudo code with coding comments to explain how the code works (Odd Even Sort)
# - Intermediate: provide choice of algorithms (easy) and website where to find algorithm (//)
# - Advanced: Code RSA. Do not include sudo code. Give outline/ inputs & function (RSA)
# - Expert: Design software to... (prompt provided)

# %% [markdown]
# Title: Tech Interview Sorting Algorithms Workshop
#
# Description: Identify what hiring managers are looking for in candidates, which coding skills you should be practicing and techniques to ace your next interview. We will practice coding interview techniques using sorting algorithms.
#
# Agenda:
#
# 1. identifying the coding interview skills you need (coding skills you should be practicing and techniques to ace your next interview)
#     1. skills report
#     2. Process I shared with Ishe (skills reports)
#     3. Ask interviewers to get insight into the interview process (Identify what hiring managers are looking for in candidates)
#     4. Informaiton from post bach degree
#         1. how to learn new technologies quickly
#     5. The coding interview
#
# 2. Teach how to do the skills identified above (practice coding interview techniques using sorting algorithms)
#     1. how to pair coding with search algorithms
#     2. top down coding interview with search algorithms
#     4. CTCI book study for interview methods with search algorithm
#     3. Job search skills
#         1. again see process I shared with Ishe
#     4. extra search algirthm(s) to practice any skill you choose with
# 3. tips on making interview prep a routine in daily life
